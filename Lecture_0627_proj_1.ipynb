# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.rcParams['font.family']='DFKai-SB'

# %%
import pandas as pd

# %%
df=pd.read_csv("heroes_information.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 11 columns):
# Unnamed: 0    734 non-null int64
# name          734 non-null object
# Gender        734 non-null object
# Eye color     734 non-null object
# Race          734 non-null object
# Hair color    734 non-null object
# Height        734 non-null float64
# Publisher     719 non-null object
# Skin color    734 non-null object
# Alignment     734 non-null object
# Weight        732 non-null float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 63.2+ KB

# %%
df[:20]
# Out:
#     Unnamed: 0               name  Gender Eye color               Race  \
# 0            0             A-Bomb    Male    yellow              Human
# 1            1         Abe Sapien    Male      blue      Icthyo Sapien
# 2            2           Abin Sur    Male      blue            Ungaran
# 3            3        Abomination    Male     green  Human / Radiation
# 4            4            Abraxas    Male      blue      Cosmic Entity
# 5            5      Absorbing Man    Male      blue              Human
# 6            6        Adam Monroe    Male      blue                  -
# 7            7       Adam Strange    Male      blue              Human
# 8            8           Agent 13  Female      blue                  -
# 9            9          Agent Bob    Male     brown              Human
# 10          10         Agent Zero    Male         -                  -
# 11          11         Air-Walker    Male      blue                  -
# ...

# %%
import numpy as np

# %%
dfmo=df[["name","Gender","Publisher","Alignment" ]]

# %%
dfmo[:20]
# Out:
#                  name  Gender          Publisher Alignment
# 0              A-Bomb    Male      Marvel Comics      good
# 1          Abe Sapien    Male  Dark Horse Comics      good
# 2            Abin Sur    Male          DC Comics      good
# 3         Abomination    Male      Marvel Comics       bad
# 4             Abraxas    Male      Marvel Comics       bad
# 5       Absorbing Man    Male      Marvel Comics       bad
# 6         Adam Monroe    Male       NBC - Heroes      good
# 7        Adam Strange    Male          DC Comics      good
# 8            Agent 13  Female      Marvel Comics      good
# 9           Agent Bob    Male      Marvel Comics      good
# 10         Agent Zero    Male      Marvel Comics      good
# 11         Air-Walker    Male      Marvel Comics       bad
# 12               Ajax    Male      Marvel Comics       bad
# 13         Alan Scott    Male          DC Comics      good
# 14        Alex Mercer    Male          Wildstorm       bad
# ...

# %%
df_data1=dfmo.groupby('Publisher')['Gender'].count()

# %%
print(df_data1)
# Out:
# Publisher
# ABC Studios            4
# DC Comics            215
# Dark Horse Comics     18
# George Lucas          14
# Hanna-Barbera          1
# HarperCollins          6
# IDW Publishing         4
# Icon Comics            4
# Image Comics          14
# J. K. Rowling          1
# J. R. R. Tolkien       1
# Marvel Comics        388
# Microsoft              1
# NBC - Heroes          19
# Rebellion              1
# Shueisha               4
# Sony Pictures          2
# South Park             1
# Star Trek              6
# SyFy                   5
# Team Epic TV           5
# Titan Books            1
# Universal Studios      1
# Wildstorm              3
# Name: Gender, dtype: int64

# %%
dfmo["Publisher"] == "Marvel Comics"
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21     False
# 22      True
# 23     False
# 24      True
# 25      True
# 26     False
# 27     False
# 28      True
# 29      True
#        ...
# 704     True
# 705     True
# 706     True
# 707     True
# 708    False
# 709     True
# 710     True
# 711     True
# 712     True
# 713    False
# 714     True
# 715    False
# 716     True
# 717     True
# 718     True
# 719     True
# 720    False
# 721     True
# 722    False
# 723     True
# 724     True
# 725     True
# 726     True
# 727     True
# 728     True
# 729     True
# 730     True
# 731    False
# 732    False
# 733    False
# Name: Publisher, Length: 734, dtype: bool

# %%
MarvelComics = (dfmo["Publisher"] == "Marvel Comics")
dfmo[MarvelComics]
# Out:
#                 name  Gender      Publisher Alignment
# 0             A-Bomb    Male  Marvel Comics      good
# 3        Abomination    Male  Marvel Comics       bad
# 4            Abraxas    Male  Marvel Comics       bad
# 5      Absorbing Man    Male  Marvel Comics       bad
# 8           Agent 13  Female  Marvel Comics      good
# 9          Agent Bob    Male  Marvel Comics      good
# 10        Agent Zero    Male  Marvel Comics      good
# 11        Air-Walker    Male  Marvel Comics       bad
# 12              Ajax    Male  Marvel Comics       bad
# 20              Ammo    Male  Marvel Comics       bad
# 22             Angel    Male  Marvel Comics      good
# 24        Angel Dust  Female  Marvel Comics      good
# 25   Angel Salvadore  Female  Marvel Comics      good
# 28         Annihilus    Male  Marvel Comics       bad
# 29           Ant-Man    Male  Marvel Comics      good
# 30        Ant-Man II    Male  Marvel Comics      good
# ...

# %%
df_data2=dfmo[MarvelComics].groupby('Gender')['Publisher'].count()

# %%
df_data2
# Out:
# Gender
# -          25
# Female    111
# Male      252
# Name: Publisher, dtype: int64

# %%
labels = 'Female','male'
size = [111,252]
plt.pie(size , labels = labels,autopct='%1.1f%%')
plt.axis('equal')
plt.show()
