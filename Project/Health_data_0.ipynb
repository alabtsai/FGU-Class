# %% [markdown]
# ## Pandas provides DataFrame
# ## import pandas

# %%
import pandas as pd

# %% [markdown]
# ## read CSV file into DataFrame

# %%
df1=pd.read_csv("NHI.csv")

# %% [markdown]
# ## data selection

# %%
df1[:5]
# Out:
#       年   週 就診類別  年齡別   縣市  腸病毒健保就診人次  健保就診總人次
# 0  2008  14   住院  0-2  台中市          0      105
# 1  2008  14   住院  0-2  台北市          2      151
# 2  2008  14   住院  0-2  台東縣          0       14
# 3  2008  14   住院  0-2  台南市          0       20
# 4  2008  14   住院  0-2  宜蘭縣          0       44

# %%
df1.iloc[:3, :5]
# Out:
#       年   週 就診類別  年齡別   縣市
# 0  2008  14   住院  0-2  台中市
# 1  2008  14   住院  0-2  台北市
# 2  2008  14   住院  0-2  台東縣

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112173 entries, 0 to 112172
# Data columns (total 7 columns):
# 年            112173 non-null int64
# 週            112173 non-null int64
# 就診類別         112173 non-null object
# 年齡別          112173 non-null object
# 縣市           112173 non-null object
# 腸病毒健保就診人次    112173 non-null int64
# 健保就診總人次      112173 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 6.0+ MB

# %%
df1.groupby('年')[['腸病毒健保就診人次']].sum()
# Out:
#       腸病毒健保就診人次
# 年
# 2008     360000
# 2009     270178
# 2010     855397
# 2011     409542
# 2012     483404
# 2013     578879
# 2014     503170
# 2015     535773
# 2016     590212
# 2017     455533
# 2018      90356

# %%
df1.pivot_table(values='腸病毒健保就診人次',index=['年','就診類別'],columns='縣市' ,aggfunc='sum')
# Out:
# 縣市           南投縣     台中市    台北市    台南市   台東縣    嘉義市   嘉義縣    基隆市    宜蘭縣  \
# 年    就診類別
# 2008 住院       14     765    739     62     6     11    30     78     13
#      門診    10056   55128  26905  41456  2934   8274  4016   4760   7288
# 2009 住院      153     986    820    115    59    186   237    124    297
#      門診     6645   46014  17825  24913  2806   6779  2948   4229   7042
# 2010 住院      352    2327   2305    251    68    408   588    388   1279
#      門診    23468  137646  68862  72263  4521  19335  8712  13457  14426
# 2011 住院      165     891   1110    142    63    189   339    207    783
#      門診     8758   55265  34228  36128  2371  10101  5179   6580   6767
# 2012 住院      128    1193   1256    212    68    149   264    206    583
#      門診     8768   68450  44295  39727  2339   8245  3790   8448   9785
# 2013 住院      271    1759   1232    207    90    207   353    187    901
#      門診    15680   90260  45548  51344  3896  10392  5209   7438  10585
# ...

# %%
dfm=df1.pivot_table(values='腸病毒健保就診人次',index='年',columns='縣市' ,
                aggfunc='sum')

# %%
print(dfm['宜蘭縣'])
# Out:
# 年
# 2008     7301
# 2009     7339
# 2010    15705
# 2011     7550
# 2012    10368
# 2013    11486
# 2014    11816
# 2015    11529
# 2016    11781
# 2017    10905
# 2018     1892
# Name: 宜蘭縣, dtype: int64
