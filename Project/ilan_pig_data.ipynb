# %%
import json
import requests
res=requests.get("http://opendataap2.e-land.gov.tw/resource/files/2018-04-17/5def5ce24ef2722286cee39d81935615.json")
print(res.text)
# Out:
# [{"\ufeff\u6d41\u6c34\u865f":"1","\u5546\u5e97\u540d\u7a31":"\u5c1a\u54c1\u8089\u865f","\u96fb\u8a71":"03-9776566","\u5730\u5740":"\u5b9c\u862d\u7e23\u982d\u57ce\u93ae\u65b0\u5efa\u91cc\u65b0\u8208\u8def276\u865f","":""},{"\ufeff\u6d41\u6c34\u865f":"2","\u5546\u5e97\u540d\u7a31":"\u6e90\u8208\u8089\u5e97","\u96fb\u8a71":"03-9882765","\u5730\u5740":"\u5b9c\u862d\u7e23\u7901\u6eaa\u9109\u7389\u77f3\u6751\u56db\u9130\u7389\u77f3\u8def37\u865f","":""},{"\ufeff\u6d41\u6c34\u865f":"3","\u5546\u5e97\u540d\u7a31":"\u5409\u5b57\u8089\u865f","\u96fb\u8a71":"03-9871588","\u5730\u5740":"\u5b9c\u862d\u7e23\u7901\u6eaa\u9109\u4e2d\u5c71\u8def2\u6bb522\u865f","":""},{"\ufeff\u6d41\u6c34\u865f":"4","\u5546\u5e97\u540d\u7a31":"\u901a\u8ca1\u8089\u865f","\u96fb\u8a71":"03-9381278","\u5730\u5740":"\u5b9c\u862d\u7e23\u5b9c\u862d\u5e02\u6771\u6e2f\u8def114\u865f","":""},{"\ufeff\u6d41\u6c34\u865f":"5","\u5546\u5e97\u540d\u7a31":"\u901a\u5927\u8089\u865f","\u96fb\u8a71":"03-9382805","\u5730\u5740":"\u5b9c
# ...

# %%
print(res.headers)
# Out:
# {'Date': 'Wed, 18 Apr 2018 05:31:03 GMT', 'Server': 'Apache/2.4.7 (Ubuntu)', 'Last-Modified': 'Tue, 17 Apr 2018 02:07:00 GMT', 'ETag': '"39ad-56a01cb314fd3"', 'Accept-Ranges': 'bytes', 'Content-Length': '14765', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'application/json'}

# %%
result=json.loads(res.text)

# %%
import pandas as pd
pd.DataFrame(result)
# Out:
#                     商店名稱                        地址           電話 ﻿流水號
# 0                   尚品肉號          宜蘭縣頭城鎮新建里新興路276號   03-9776566    1
# 1                   源興肉店         宜蘭縣礁溪鄉玉石村四鄰玉石路37號   03-9882765    2
# 2                   吉字肉號            宜蘭縣礁溪鄉中山路2段22號   03-9871588    3
# 3                   通財肉號             宜蘭縣宜蘭市東港路114號   03-9381278    4
# 4                   通大肉號             宜蘭縣宜蘭市東港路112號   03-9382805    5
# 5                   高翊肉號            宜蘭縣宜蘭市中山路5段40號   03-9283164    6
# 6                   三吉肉號              宜蘭縣宜蘭市東港路84號   03-9301995    7
# 7                   松興肉號          宜蘭縣宜蘭市光復路125之10號   03-9332358    8
# 8                   寶鋒肉號             宜蘭縣宜蘭市光復路125號   03-9327030    9
# 9                   武強肉號  宜蘭縣宜蘭市宜興路一段60號（綠九市場第42攤）   03-9331901   10
# 10                  老張肉號              宜蘭縣宜蘭市崇聖街69號                11
# 11              豬寶貝豬肉專賣店              宜蘭縣宜蘭市小東路13號   03-9315649   12
# 12                   金發號               宜蘭縣羅東鎮民族路7號                13
# ...
