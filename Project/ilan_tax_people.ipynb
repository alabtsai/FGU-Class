# %%
import json
import requests
res=requests.get("http://opendataap2.e-land.gov.tw/resource/files/2017-10-02/31f50c944180429aa489503b0a0de914.json")
print(res.text)
# Out:
# [{"\ufeff\u9805\u76ee(\u4f9d\u5e74\u9f61\uff0c\u5b78\u6b77\uff0c\u8077\u7b49\uff0c\u5e74\u8cc7)":"24\u6b72\u4ee5\u4e0b","\u7e3d\u8a08105\u5e74\u5e95":"0","\u7537105\u5e74\u5e95":"0","\u5973105\u5e74\u5e95":"0"},{"\ufeff\u9805\u76ee(\u4f9d\u5e74\u9f61\uff0c\u5b78\u6b77\uff0c\u8077\u7b49\uff0c\u5e74\u8cc7)":"25-29\u6b72","\u7e3d\u8a08105\u5e74\u5e95":"26","\u7537105\u5e74\u5e95":"6","\u5973105\u5e74\u5e95":"20"},{"\ufeff\u9805\u76ee(\u4f9d\u5e74\u9f61\uff0c\u5b78\u6b77\uff0c\u8077\u7b49\uff0c\u5e74\u8cc7)":"30-39\u6b72","\u7e3d\u8a08105\u5e74\u5e95":"49","\u7537105\u5e74\u5e95":"18","\u5973105\u5e74\u5e95":"31"},{"\ufeff\u9805\u76ee(\u4f9d\u5e74\u9f61\uff0c\u5b78\u6b77\uff0c\u8077\u7b49\uff0c\u5e74\u8cc7)":"40-49\u6b72","\u7e3d\u8a08105\u5e74\u5e95":"49","\u7537105\u5e74\u5e95":"11","\u5973105\u5e74\u5e95":"38"},{"\ufeff\u9805\u76ee(\u4f9d\u5e74\u9f61\uff0c\u5b78\u6b77\uff0c\u8077\u7b49\uff0c\u5e74\u8cc7)":"50-59\u6b72","\u7e3d\u8a08105\u5e74\u5e95":"31","\u7537105\u5e74\u5e95":"9","\u
# ...

# %%
print(res.headers)
# Out:
# {'Date': 'Wed, 18 Apr 2018 05:51:54 GMT', 'Server': 'Apache/2.4.7 (Ubuntu)', 'Last-Modified': 'Mon, 02 Oct 2017 01:53:14 GMT', 'ETag': '"1a69-55a86a345a603"', 'Accept-Ranges': 'bytes', 'Content-Length': '6761', 'Keep-Alive': 'timeout=5, max=100', 'Content-Type': 'application/json', 'Connection': 'keep-alive'}

# %%
result=json.loads(res.text)
print(result)
# Out:
# [{'\ufeff項目(依年齡，學歷，職等，年資)': '24歲以下', '總計105年底': '0', '男105年底': '0', '女105年底': '0'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '25-29歲', '總計105年底': '26', '男105年底': '6', '女105年底': '20'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '30-39歲', '總計105年底': '49', '男105年底': '18', '女105年底': '31'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '40-49歲', '總計105年底': '49', '男105年底': '11', '女105年底': '38'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '50-59歲', '總計105年底': '31', '男105年底': '9', '女105年底': '22'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '60-65歲', '總計105年底': '15', '男105年底': '5', '女105年底': '10'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '66歲以上', '總計105年底': '0', '男105年底': '0', '女105年底': '0'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '總計', '總計105年底': '170', '男105年底': '49', '女105年底': '121'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '博士', '總計105年底': '0', '男105年底': '0', '女105年底': '0'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '碩士', '總計105年底': '18', '男105年底': '5', '女105年底': '13'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '大學', '總計105年底': '93', '男105年底': '28', '女105年底': '65'}, {'\ufeff項目(依年齡，學歷，職等，年資)': '專科', '總計105年底': '41', '男105年底': '11', '女1
# ...

# %%
import pandas as pd
pd.DataFrame(result)
# Out:
#    女105年底 男105年底 總計105年底 ﻿項目(依年齡，學歷，職等，年資)
# 0       0      0       0             24歲以下
# 1      20      6      26            25-29歲
# 2      31     18      49            30-39歲
# 3      38     11      49            40-49歲
# 4      22      9      31            50-59歲
# 5      10      5      15            60-65歲
# 6       0      0       0             66歲以上
# 7     121     49     170                總計
# 8       0      0       0                博士
# 9      13      5      18                碩士
# 10     65     28      93                大學
# 11     30     11      41                專科
# 12     11      4      15               高中職
# 13      2      1       3           國(初)中以下
# 14    121     49     170                總計
# 15      1      0       1             簡任(派)
# 16     45     17      62             薦任(派)
# 17     32     18      50             委任(派)
# 18     11      2      13              約雇人員
# 19      0      3       3              約聘人員
# 20     17      0      17              臨時人員
# ...
