# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.style.available
# Out:
# ['fivethirtyeight',
#  'seaborn-pastel',
#  'ggplot',
#  'seaborn-ticks',
#  'seaborn-notebook',
#  'seaborn-dark',
#  'seaborn-talk',
#  'seaborn-bright',
#  'dark_background',
#  'bmh',
#  'fast',
#  'seaborn-paper',
#  'seaborn-whitegrid',
#  'seaborn-poster',
#  'seaborn-muted',
#  'seaborn-dark-palette',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-darkgrid',
#  'grayscale',
#  'seaborn-colorblind',
#  '_classic_test',
#  'seaborn-white',
#  'seaborn-deep',
#  'classic']

# %%
plt.style.use('ggplot')

# %%
s=np.random.uniform(0,1,100)

# %%
print(type(s))
# Out:
# <class 'numpy.ndarray'>

# %%
s
# Out:
# array([ 0.85086508,  0.73504556,  0.62833879,  0.96974066,  0.39165754,
#         0.4998969 ,  0.56445285,  0.13597782,  0.0160497 ,  0.57437257,
#         0.02461153,  0.33745479,  0.82824236,  0.87795808,  0.72892438,
#         0.70688708,  0.83173845,  0.66432371,  0.44550315,  0.53169836,
#         0.05165358,  0.9463346 ,  0.75579628,  0.87562796,  0.37306455,
#         0.82169601,  0.27070495,  0.39061987,  0.62603392,  0.75268041,
#         0.81153189,  0.49539302,  0.3423976 ,  0.20858783,  0.00136252,
#         0.73578109,  0.84656818,  0.12451256,  0.32995177,  0.66891708,
#         0.91440628,  0.06927494,  0.13412059,  0.16696701,  0.09979699,
#         0.95574558,  0.35298146,  0.37426719,  0.05023164,  0.11105669,
#         0.33943792,  0.61307764,  0.58111591,  0.43335091,  0.82834586,
#         0.19578362,  0.10570555,  0.01926785,  0.8921351 ,  0.91590508,
#         0.41646345,  0.63820006,  0.71895817,  0.23981321,  0.29915073,
# ...

# %%
plt.plot(s)
